# %% [markdown]
# ## Homework: Multilingual Embedding-based Machine Translation (7 points)

# %% [markdown]
# **In this homework** **<font color='red'>YOU</font>** will make machine translation system without using parallel corpora, alignment, attention, 100500 depth super-cool recurrent neural network and all that kind superstuff.
#
# But even without parallel corpora this system can be good enough (hopefully).
#
# For our system we choose two kindred Slavic languages: Ukrainian and Russian.

# %% [markdown]
# ### Feel the difference!
#
# (_синій кіт_ vs. _синій кит_)

# %% [markdown]
# ![blue_cat_blue_whale.png](https://github.com/yandexdataschool/nlp_course/raw/master/resources/blue_cat_blue_whale.png)

# %% [markdown]
# ### Fragment of the Swadesh list for some slavic languages
#
# The Swadesh list is a lexicostatistical stuff. It's named after American linguist Morris Swadesh and contains basic lexis. This list are used to define subgroupings of languages, its relatedness.
#
# So we can see some kind of word invariance for different Slavic languages.
#
#
# | Russian         | Belorussian              | Ukrainian               | Polish             | Czech                         | Bulgarian            |
# |-----------------|--------------------------|-------------------------|--------------------|-------------------------------|-----------------------|
# | женщина         | жанчына, кабета, баба    | жінка                   | kobieta            | žena                          | жена                  |
# | мужчина         | мужчына                  | чоловік, мужчина        | mężczyzna          | muž                           | мъж                   |
# | человек         | чалавек                  | людина, чоловік         | człowiek           | člověk                        | човек                 |
# | ребёнок, дитя   | дзіця, дзіцёнак, немаўля | дитина, дитя            | dziecko            | dítě                          | дете                  |
# | жена            | жонка                    | дружина, жінка          | żona               | žena, manželka, choť          | съпруга, жена         |
# | муж             | муж, гаспадар            | чоловiк, муж            | mąż                | muž, manžel, choť             | съпруг, мъж           |
# | мать, мама      | маці, матка              | мати, матір, неня, мама | matka              | matka, máma, 'стар.' mateř    | майка                 |
# | отец, тятя      | бацька, тата             | батько, тато, татусь    | ojciec             | otec                          | баща, татко           |
# | много           | шмат, багата             | багато                  | wiele              | mnoho, hodně                  | много                 |
# | несколько       | некалькі, колькі         | декілька, кілька        | kilka              | několik, pár, trocha          | няколко               |
# | другой, иной    | іншы                     | інший                   | inny               | druhý, jiný                   | друг                  |
# | зверь, животное | жывёла, звер, істота     | тварина, звір           | zwierzę            | zvíře                         | животно               |
# | рыба            | рыба                     | риба                    | ryba               | ryba                          | риба                  |
# | птица           | птушка                   | птах, птиця             | ptak               | pták                          | птица                 |
# | собака, пёс     | сабака                   | собака, пес             | pies               | pes                           | куче, пес             |
# | вошь            | вош                      | воша                    | wesz               | veš                           | въшка                 |
# | змея, гад       | змяя                     | змія, гад               | wąż                | had                           | змия                  |
# | червь, червяк   | чарвяк                   | хробак, черв'як         | robak              | červ                          | червей                |
# | дерево          | дрэва                    | дерево                  | drzewo             | strom, dřevo                  | дърво                 |
# | лес             | лес                      | ліс                     | las                | les                           | гора, лес             |
# | палка           | кій, палка               | палиця                  | patyk, pręt, pałka | hůl, klacek, prut, kůl, pálka | палка, пръчка, бастун |

# %% [markdown]
# But the context distribution of these languages demonstrates even more invariance. And we can use this fact for our for our purposes.

# %% [markdown]
# ## Data

# %%
import gensim
import numpy as np
from gensim.models import KeyedVectors

# %% [markdown]
# Download embeddings here:
# * [cc.uk.300.vec.zip](https://yadi.sk/d/9CAeNsJiInoyUA)
# * [cc.ru.300.vec.zip](https://yadi.sk/d/3yG0-M4M8fypeQ)

# %% [markdown]
# Load embeddings for ukrainian and russian.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
uk_emb = KeyedVectors.load_word2vec_format("/content/drive/MyDrive/ysda/cc.uk.300.vec")

# %%
ru_emb = KeyedVectors.load_word2vec_format("/content/drive/MyDrive/ysda/cc.ru.300.vec")

# %%
ru_emb.most_similar([ru_emb["август"]], topn=10)
# Out:
# [('август', 1.0000001192092896),
#  ('июль', 0.9383152723312378),
#  ('сентябрь', 0.9240029454231262),
#  ('июнь', 0.9222574830055237),
#  ('октябрь', 0.9095539450645447),
#  ('ноябрь', 0.8930036425590515),
#  ('апрель', 0.8729087114334106),
#  ('декабрь', 0.8652557730674744),
#  ('март', 0.8545795679092407),
#  ('февраль', 0.8401415944099426)]

# %%
uk_emb.most_similar([uk_emb["серпень"]])
# Out:
# [('серпень', 0.9999998807907104),
#  ('липень', 0.9096441268920898),
#  ('вересень', 0.9016969203948975),
#  ('червень', 0.8992518782615662),
#  ('жовтень', 0.8810408115386963),
#  ('листопад', 0.8787633180618286),
#  ('квітень', 0.8592804670333862),
#  ('грудень', 0.8586863279342651),
#  ('травень', 0.840811014175415),
#  ('лютий', 0.8256431221961975)]

# %%
ru_emb.most_similar([uk_emb["серпень"]])
# Out:
# [('Недопустимость', 0.24435284733772278),
#  ('конструктивность', 0.23293082416057587),
#  ('офор', 0.23256804049015045),
#  ('deteydlya', 0.230317160487175),
#  ('пресечении', 0.22632381319999695),
#  ('одностороннего', 0.22608886659145355),
#  ('подход', 0.2230587750673294),
#  ('иболее', 0.22003726661205292),
#  ('2015Александр', 0.21872766315937042),
#  ('конструктивен', 0.21796567738056183)]

# %% [markdown]
# Load small dictionaries for correspoinding words pairs as trainset and testset.

# %%
def load_word_pairs(filename):
    uk_ru_pairs = []
    uk_vectors = []
    ru_vectors = []
    with open(filename, "r") as inpf:
        for line in inpf:
            uk, ru = line.rstrip().split("\t")
            if uk not in uk_emb or ru not in ru_emb:
                continue
            uk_ru_pairs.append((uk, ru))
            uk_vectors.append(uk_emb[uk])
            ru_vectors.append(ru_emb[ru])
    return uk_ru_pairs, np.array(uk_vectors), np.array(ru_vectors)

# %%
uk_ru_train, X_train, Y_train = load_word_pairs("/content/drive/MyDrive/ysda/ukr_rus.train.txt")

# %%
uk_ru_test, X_test, Y_test = load_word_pairs("/content/drive/MyDrive/ysda/ukr_rus.test.txt")

# %%
uk_ru_train
# Out:
# [('iснує', 'существует'),
#  ('абияк', 'как-нибудь'),
#  ('або', 'или'),
#  ('або', 'ли'),
#  ('абсолютно', 'совершенно'),
#  ('абсолютно', 'совсем'),
#  ('автомобіль', 'автомобиль'),
#  ('автомобіль', 'вагон'),
#  ('агов', 'эй'),
#  ('аґрус', 'крыжовник'),
#  ('адже', 'ведь'),
#  ('адміністрація', 'администрация'),
#  ('адреса', 'адрес'),
#  ('академік', 'академик'),
#  ('академія', 'академия'),
#  ('актор', 'артист'),
#  ('акуратно', 'аккуратно'),
#  ('акції', 'действие'),
#  ('акція', 'акция'),
#  ('але', 'же'),
#  ('але', 'зато'),
#  ('але', 'но'),
#  ('американець', 'американец'),
#  ('аналіз', 'анализ'),
#  ('арешт', 'арест'),
#  ('аркушів', 'листы'),
#  ('армія', 'войско'),
#  ('атрибут', 'признак'),
#  ('багато', 'гораздо'),
#  ('багато', 'многие'),
#  ('багато', 'много'),
#  ('багато', 'многое'),
#  ('базовий', 'база'),
#  ('бак', 'танк'),
#  ('батальйон', 'батальон'),
#  ('батьки', 'родители'),
#  ('батьків', 'отцы'),
#  ('батьківщина', 'родина'),
#  ('батько', 'отец'),
#  ('бачити', 'видать'),
#  ('бачити', 'видеть'),
#  ('безглуздий', 'бессмысленный'),
#  ('безпека', 'безопасность'),
#  ('безпосередньо', 'непосредственно'),
#  ('березень', 'март'),
#  ('битися', 'биться'),
#  ('битися', 'драться'),
#  ('бібліотека', 'библиотека'),
#  ('біг', 'бег'),
#  ('біда', 'беда'),
#  ('білизна', 'белье'),
#  ('білок', 'белок'),
#  ('більше', 'более'),
#  ('більшість', 'большинство'),
#  ('благати', 'умолять'),
#  ('благородний', 'благородный'),
#  ('блиск', 'блеск'),
#  ('блискучий', 'блестящий'),
#  ('блищати', 'блестеть'),
#  ('бож', 'ибо'),
#  ('бойовик', 'боец'),
#  ('болісно', 'больно'),
#  ('борг', 'долг'),
#  ('боротися', 'бороться'),
#  ('боротьба', 'борьба'),
#  ('боягуз', 'трус'),
#  ('бракувати', 'недоставать'),
#  ('бригадир', 'старшина'),
#  ('брови', 'бровь'),
#  ('бродити', 'бродить'),
#  ('бруд', 'грязь'),
#  ('брудно', 'грязно'),
#  ('брюки', 'штаны'),
#  ('буде', 'быть'),
#  ('будильник', 'тревога'),
#  ('будівля', 'здание'),
#  ('будівля', 'строение'),
#  ('будувати', 'строить'),
#  ('будь-який', 'любой'),
#  ('бути', 'найтись'),
#  ('бути', 'явиться'),
#  ('вага', 'вес'),
#  ('вага', 'масса'),
#  ('вагітність', 'беременность'),
#  ('важкий', 'тяжело'),
#  ('валятися', 'валяться'),
#  ('вам', 'тобой'),
#  ('вантажівка', 'грузовик'),
#  ('вантажний', 'грузовой'),
#  ('вапняк', 'известняк'),
#  ('варіант', 'вариант'),
#  ('вартість', 'значение'),
#  ('вартість', 'стоимость'),
#  ('вартість', 'стоить'),
#  ('ватажок', 'предводитель'),
#  ('ваш', 'твой'),
#  ('вбивати', 'убивать'),
#  ('вбивство', 'убийство'),
#  ('вбивця', 'убийца'),
#  ('вважати', 'считать'),
#  ('ввічливо', 'вежливо'),
#  ('в', 'во'),
#  ('вголос', 'вслух'),
#  ('вгору', 'вверх'),
#  ('вдавалося', 'удаваться'),
#  ('ведмідь', 'медведь'),
#  ('велетень', 'великан'),
#  ('Великдень', 'Пасха'),
#  ('величезний', 'громадный'),
#  ('вересень', 'сентябрь'),
#  ('версія', 'версия'),
#  ('вертоліт', 'вертолет'),
#  ('верховенство', 'правило'),
#  ('весілля', 'свадьба'),
#  ('вечеря', 'ужин'),
#  ('взагалi', 'вообще'),
#  ('взагалі-то', 'собственно'),
#  ('вибір', 'выбор'),
#  ('вибори', 'выборы'),
#  ('вибрати', 'выбрать'),
#  ('вибратися', 'выбраться'),
#  ('вибух', 'взрыв'),
#  ('вивезти', 'вынуть'),
#  ('вивести', 'вывести'),
#  ('вивести', 'вытащить'),
#  ('вивчати', 'изучать'),
#  ('вигадати', 'придумать'),
#  ('видавати', 'выдавать'),
#  ('видавати', 'выдать'),
#  ('видалити', 'снимать'),
#  ('визначати', 'определять'),
#  ('виїхати', 'выехать'),
#  ('викинути', 'выбросить'),
#  ('виклик', 'вызов'),
#  ('виключити', 'исключить'),
#  ('виключно', 'исключительно'),
#  ('виконання', 'исполнение'),
#  ('виконувати', 'выполнять'),
#  ('використання', 'использование'),
#  ('використовувати', 'пользоваться'),
#  ('використовуватися', 'использоваться'),
#  ('вилучення', 'исключение'),
#  ('вимовляти', 'произносить'),
#  ('вимога', 'требование'),
#  ('виникнення', 'появление'),
#  ('виняток', 'исключение'),
#  ('випадковий', 'случайный'),
#  ('випадково', 'случайно'),
#  ('випадок', 'случай'),
#  ('випити', 'выпить'),
#  ('випити', 'пить'),
#  ('випробувати', 'испытать'),
#  ('випускати', 'выпускать'),
#  ('вираз', 'выражение'),
#  ('виразно', 'отчетливо'),
#  ('вирватися', 'вырваться'),
#  ('вирішити', 'разрешить'),
#  ('вирішити', 'решать'),
#  ('вирішуватися', 'решаться'),
#  ('виробляти', 'производить'),
#  ('виробництво', 'производство'),
#  ('вирушати', 'отправляться'),
#  ('висвітлити', 'осветить'),
#  ('висловити', 'выразить'),
#  ('висловлення', 'высказывание'),
#  ('висновки', 'выводы'),
#  ('висновок', 'вывод'),
#  ('висновок', 'заключение'),
#  ('високо', 'высоко'),
#  ('висота', 'высота'),
#  ('виставити', 'выставить'),
#  ('виставка', 'выставка'),
#  ('вистачить', 'довольно'),
#  ('виступ', 'выступление'),
#  ('витягнути', 'вытянуть'),
#  ('виховання', 'воспитание'),
#  ('виходити', 'исходить'),
#  ('вищезгадане', 'вышеупомянутое'),
#  ('відбуватися', 'происходить'),
#  ('відвернутися', 'отвернуться'),
#  ('відвідувач', 'посетитель'),
#  ('відгадати', 'догадаться'),
#  ('відгукнутися', 'отозваться'),
#  ('відділу', 'отдел'),
#  ('відірвати', 'оторвать'),
#  ('відкрити', 'открывать'),
#  ('відкрити', 'открыть'),
#  ('відкрити', 'открыться'),
#  ('відкриття', 'открытие'),
#  ('відлуння', 'эхо'),
#  ('відмінність', 'отличие'),
#  ('відмінно', 'отлично'),
#  ('відміну', 'отличие'),
#  ('відмова', 'отказ'),
#  ('відмовити', 'отказаться'),
#  ('відмовитися', 'падать'),
#  ('відмовлятися', 'отказываться'),
#  ('відносний', 'родственник'),
#  ('відображати', 'задуматься'),
#  ('відомості', 'внимание'),
#  ('від', 'от'),
#  ('відповідальність', 'ответственность'),
#  ('відповідати', 'соответствовать'),
#  ('відповідь', 'ответ'),
#  ('відпочивати', 'отдыхать'),
#  ('відпочинок', 'отдых'),
#  ('відпочити', 'отдохнуть'),
#  ('відправити', 'отправить'),
#  ('відправити', 'послать'),
#  ('відправити', 'посылать'),
#  ('відправити', 'прислать'),
#  ('відправити', 'присылать'),
#  ('відправити', 'слать'),
#  ('відпустку', 'отпуск'),
#  ('відро', 'ведро'),
#  ('відсоток', 'процент'),
#  ('відстань', 'даль'),
#  ('відстань', 'расстояние'),
#  ('відсутність', 'отсутствие'),
#  ('відходити', 'отойти'),
#  ('відчай', 'отчаяние'),
#  ('відчувати', 'ощущать'),
#  ('відчувати', 'почувствовать'),
#  ('відчувати', 'чувствовать'),
#  ('відчути', 'ощутить'),
#  ('відчуття', 'ощущение'),
#  ('відчуття', 'чувство'),
#  ('відьма', 'ведьма'),
#  ('віза', 'виза'),
#  ('візит', 'визит'),
#  ('візок', 'тележка'),
#  ('війна', 'война'),
#  ('війн', 'войны'),
#  ('військовий', 'военный'),
#  ('вікна', 'окно'),
#  ('він', 'он'),
#  ('вірити', 'полагать'),
#  ('вірші', 'стихи'),
#  ('вісімдесят', 'восемьдесят'),
#  ('вісімсот', 'восемьсот'),
#  ('вітер', 'ветер'),
#  ('вітчизняний', 'отечественный'),
#  ('вічко', 'глазок'),
#  ('вічно', 'вечно'),
#  ('вказати', 'указать'),
#  ('вказівка', 'указание'),
#  ('вказувати', 'указывать'),
#  ('включити', 'включить'),
#  ('вкрай', 'крайне'),
#  ('влада', 'власть'),
#  ('власник', 'владелец'),
#  ('власність', 'собственность'),
#  ('властивість', 'свойство'),
#  ('властивості', 'свойства'),
#  ('влаштовувати', 'устраивать'),
#  ('влаштуватися', 'устроиться'),
#  ('вовна', 'шерсть'),
#  ('вогник', 'огонек'),
#  ('води', 'воды'),
#  ('водій', 'шофер'),
#  ('воїн', 'воин'),
#  ('володіти', 'владеть'),
#  ('волосся', 'волос'),
#  ('вона', 'она'),
#  ('вони', 'они'),
#  ('ворог', 'враг'),
#  ('вороги', 'враги'),
#  ('ворота', 'ворот'),
#  ('ворушитися', 'шевелиться'),
#  ('восени', 'осень'),
#  ('восьмий', 'восьмой'),
#  ('впасти', 'спасть'),
#  ('вперед', 'вперёд'),
#  ('вперше', 'впервые'),
#  ('вплив', 'влияние'),
#  ('вплив', 'воздействие'),
#  ('враження', 'впечатление'),
#  ('вразити', 'поразить'),
#  ('вранці', 'утро'),
#  ('всередині', 'внутри'),
#  ('всередину', 'внутрь'),
#  ('всерйоз', 'всерьез'),
#  ('все-таки', 'хоть'),
#  ('все-таки', 'хотя'),
#  ('всі', 'весь'),
#  ('вставати', 'вставать'),
#  ('встигати', 'успевать'),
#  ('вступити', 'вступить'),
#  ('втекти', 'сбежать'),
#  ('втекти', 'скрыться'),
#  ('втекти', 'убежать'),
#  ('втомитися', 'устать'),
#  ('втрата', 'потеря'),
#  ('втратити', 'потерять'),
#  ('втратити', 'терять'),
#  ('вузол', 'узел'),
#  ('вуха', 'уши'),
#  ('вчасно', 'вовремя'),
#  ('вчинок', 'поступок'),
#  ('вчора', 'вчера'),
#  ('вчорашній', 'вчерашний'),
#  ('ґава', 'ворона'),
#  ('гай', 'роща'),
#  ('ганок', 'крыльцо'),
#  ('ґанок', 'крыльцо'),
#  ('ганчірка', 'тряпка'),
#  ('гарбуз', 'тыква'),
#  ('гармата', 'пушка'),
#  ('гарно', 'красиво'),
#  ('гвинтівка', 'винтовка'),
#  ('генеральний', 'генеральный'),
#  ('геть', 'прочь'),
#  ('гігантський', 'гигантский'),
#  ('гідний', 'достойный'),
#  ('гідність', 'достоинство'),
#  ('гілка', 'ветка'),
#  ('гіркий', 'горький'),
#  ('гірський', 'горный'),
#  ('глибина', 'глубина'),
#  ('глибоко', 'глубоко'),
#  ('глузувати', 'насмехаться'),
#  ('глядач', 'зритель'),
#  ('глянути', 'глянуть'),
#  ('гнати', 'гнать'),
#  ('говорити', 'говорить'),
#  ('година', 'час'),
#  ('годинник', 'часы'),
#  ('годувати', 'кормить'),
#  ('голосно', 'громко'),
#  ('гомілка', 'голень'),
#  ('гордість', 'гордость'),
#  ('гори', 'горы'),
#  ('горі', 'гора'),
#  ('горілка', 'водка'),
#  ('горілці', 'водка'),
#  ('город', 'огород'),
#  ('госпіталь', 'госпиталь'),
#  ('господа', 'господь'),
#  ('господиня', 'хозяйка'),
#  ('готель', 'гостиница'),
#  ('готувати', 'варить'),
#  ('грати', 'играть'),
#  ('ґрати', 'решетка'),
#  ('грізний', 'грозный'),
#  ('гріх', 'грех'),
#  ('громадян', 'граждане'),
#  ('громадянство', 'гражданство'),
#  ('грубий', 'грубый'),
#  ('групи', 'группа'),
#  ('групи', 'отряд'),
#  ('губи', 'губы'),
#  ('гудзик', 'пуговица'),
#  ('гумор', 'юмор'),
#  ('гуркіт', 'грохот'),
#  ('гучний', 'громкий'),
#  ('дама', 'девушка'),
#  ('дані', 'сведение'),
#  ('дар', 'подарок'),
#  ('дати', 'отдавать'),
#  ('дати', 'отдать'),
#  ('двадцять', 'двадцать'),
#  ('дванадцять', 'двенадцать'),
#  ('дверцята', 'дверца'),
#  ('двигун', 'двигатель'),
#  ('дворах', 'дворы'),
#  ('декларувати', 'заявить'),
#  ('де', 'куда'),
#  ('демократія', 'демократия'),
#  ('десять', 'десяток'),
#  ('дешевий', 'дешевый'),
#  ('дещо', 'кое-что'),
#  ('джерело', 'источник'),
#  ('дзеркала', 'зеркала'),
#  ('дивак', 'чудак'),
#  ('дивитися', 'посмотреть'),
#  ('дивно', 'удивительно'),
#  ('дим', 'дым'),
#  ('дитинство', 'детство'),
#  ('дихання', 'дыхание'),
#  ('дихати', 'дышать'),
#  ('диявол', 'дьявол'),
#  ('дівка', 'девка'),
#  ('дівчатко', 'девица'),
#  ('дівчина', 'девочка'),
#  ('дід', 'дедушка'),
#  ('дійсність', 'действительность'),
#  ('дійсно', 'верно'),
#  ('дійсно', 'действительно'),
#  ('дійсно', 'неужели'),
#  ('діловий', 'деловой'),
#  ('діставати', 'доставать'),
#  ('дістати', 'достать'),
#  ('дістатися', 'достаться'),
#  ('діти', 'дети'),
#  ('діяти', 'выступать'),
#  ('для', 'повезти'),
#  ('доба', 'сутки'),
#  ('добитися', 'добиться'),
#  ('довести', 'привезти'),
#  ('доводити', 'доказывать'),
#  ('договір', 'договор'),
#  ('догори', 'вверх'),
#  ('додати', 'добавить'),
#  ('додати', 'добавлять'),
#  ('додатковий', 'дополнительный'),
#  ('додаток', 'приложение'),
#  ('дозвіл', 'разрешение'),
#  ('дозволяти', 'пусть'),
#  ('доказ', 'доказательство'),
#  ('долар', 'доллар'),
#  ('домовина', 'гроб'),
#  ('домовитися', 'договориться'),
#  ('домовитися', 'согласиться'),
#  ('допит', 'допрос'),
#  ('доповідь', 'доклад'),
#  ('доповісти', 'доложить'),
#  ('допускаються', 'приняться'),
#  ('допустимий', 'допустимый'),
#  ('дорога', 'дорогой'),
#  ('досвід', 'опыт'),
#  ('досвідчений', 'опытный'),
#  ('досить', 'весьма'),
#  ('дослідження', 'исследование'),
#  ('доставити', 'доставить'),
#  ('достатньо', 'честно'),
#  ('досягнення', 'достижение'),
#  ('досягти', 'добраться'),
#  ('досягти', 'дойти'),
#  ('досягти', 'достигнуть'),
#  ('дотик', 'касание'),
#  ('доходити', 'доходить'),
#  ('дочекатися', 'дождаться'),
#  ('дощі', 'дожди'),
#  ('дратує', 'раздражает'),
#  ('дрібниця', 'мелочь'),
#  ('другий', 'второй'),
#  ('друг', 'приятель'),
#  ('дружина', 'жена'),
#  ('дружин', 'жёны'),
#  ('друкарня', 'типография'),
#  ('друк', 'печать'),
#  ('друкувати', 'печатать'),
#  ('дуже', 'очень'),
#  ('дурість', 'глупость'),
#  ('душ', 'души'),
#  ('душевний', 'душевный'),
#  ('екіпаж', 'экипаж'),
#  ('економіка', 'экономика'),
#  ('екран', 'экран'),
#  ('експерт', 'специалист'),
#  ('енергія', 'энергия'),
#  ('епоха', 'эпоха'),
#  ('етап', 'этап'),
#  ('єврейський', 'еврейский'),
#  ('європа', 'европа'),
#  ('європейський', 'европейский'),
#  ('жалість', 'жалость'),
#  ('жаль', 'сожаление'),
#  ('жалюгідний', 'жалкий'),
#  ('жартувати', 'шутить'),
#  ('жахливий', 'ужасный'),
#  ('жахливо', 'ужасно'),
#  ('жах', 'ужас'),
#  ('жебрак', 'попрошайка'),
#  ('жирний', 'жирный'),
#  ('жити', 'жить'),
#  ('жити', 'прожить'),
#  ('жито', 'рожь'),
#  ('жінка', 'женщина'),
#  ('жовтень', 'октябрь'),
#  ('жорсткий', 'жесткий'),
#  ('жорстокий', 'жестокий'),
#  ('журба', 'печаль'),
#  ('журналіст', 'журналист'),
#  ('заборонити', 'запретить'),
#  ('забрати', 'забрать'),
#  ('забути', 'забывать'),
#  ('забути', 'забыть'),
#  ('завантажити', 'загрузить'),
#  ('завдання', 'задание'),
#  ('завдяки', 'благодаря'),
#  ('завжди', 'всегда'),
#  ('завзято', 'рьяно'),
#  ('завірюха', 'вьюга'),
#  ('загал', 'общественность'),
#  ('загальне', 'генерал'),
#  ('загальний', 'всеобщий'),
#  ('загальний', 'общий'),
#  ('загарбники', 'захватчики'),
#  ('загартувати', 'закалить'),
#  ('загибель', 'гибель'),
#  ('загін', 'отряд'),
#  ('заглядати', 'заглядывать'),
#  ('загрожувати', 'грозить'),
#  ('загроза', 'угроза'),
#  ('задумливо', 'задумчиво'),
#  ('задуха', 'духота'),
#  ('заєць', 'заяц'),
#  ('зажадати', 'потребовать'),
#  ('зазвичай', 'обычно'),
#  ('заздалегiдь', 'предварительно'),
#  ('заздалегідь', 'заранее'),
#  ('зайнятися', 'заняться'),
#  ('закінчення', 'окончание'),
#  ('закінчитися', 'закончиться'),
#  ('закінчується', 'концы'),
#  ('заклик', 'звонок'),
#  ('закрити', 'близко'),
#  ('закрити', 'закрыть'),
#  ('закурити', 'закурить'),
#  ('залежати', 'зависеть'),
#  ('залежність', 'зависимость'),
#  ('залишити', 'оставлять'),
#  ('залишитися', 'остаться'),
#  ('залишок', 'остаток'),
#  ('залізо', 'железо'),
#  ('замах', 'покушение'),
#  ('замах', 'попытка'),
#  ('заміж', 'замуж'),
#  ('замінити', 'заменить'),
#  ('замість', 'вместо'),
#  ('замкнути', 'запереть'),
#  ('замовити', 'заказать'),
#  ('замовчати', 'замолчать'),
#  ('занадто', 'слишком'),
#  ('заперечувати', 'возражать'),
#  ('записати', 'записать'),
#  ('запис', 'запись'),
#  ('записки', 'записка'),
#  ('заплакати', 'заплакать'),
#  ('заплатити', 'заплатить'),
#  ('зараз', 'сейчас'),
#  ('заробити', 'заработать'),
#  ('засада', 'принцип'),
#  ('засіб', 'средство'),
#  ('заслання', 'ссылка'),
#  ('заснути', 'заснуть'),
#  ('заснути', 'уснуть'),
#  ('заспокоїтися', 'успокоиться'),
#  ('застосовувати', 'применять'),
#  ('застосування', 'применение'),
#  ('заступник', 'заместитель'),
#  ('зауважувати', 'замечать'),
#  ('захват', 'восторг'),
#  ('захист', 'охрана'),
#  ('захищати', 'защищать'),
#  ('захід', 'запад'),
#  ('захлинутися', 'захлебнуться'),
#  ('заховати', 'спрятать'),
#  ('захопити', 'захватить'),
#  ('захоплювати', 'захватить'),
#  ('зберегти', 'сохранить'),
#  ('зберігати', 'хранить'),
#  ('збирати', 'собирать'),
#  ('збирати', 'собрать'),
#  ('збити', 'сбить'),
#  ('збір', 'сбор'),
#  ('зборка', 'строй'),
#  ('звiльнення', 'освобождение'),
#  ('зважити', 'взвесить'),
#  ('зважитися', 'решиться'),
#  ('звалитися', 'рухнуть'),
#  ('звання', 'звание'),
#  ('звернення', 'обращение'),
#  ('звертатися', 'обращаться'),
#  ('зверху', 'сверху'),
#  ('звичка', 'привычка'),
#  ('звичний', 'привычный'),
#  ('звідки', 'откуда'),
#  ('звідси', 'отсюда'),
#  ('звідти', 'оттуда'),
#  ('звільнити', 'освободить'),
#  ('звіт', 'отчет'),
#  ('зворотний', 'обратный'),
#  ('звучати', 'звучать'),
#  ('згадка', 'упоминание'),
#  ('згідно', 'согласно'),
#  ('згодом', 'впоследствии'),
#  ('згорнути', 'катить'),
#  ('згорнути', 'свернуть'),
#  ('зграя', 'стая'),
#  ('здаватися', 'казаться'),
#  ('здібності', 'способность'),
#  ('здійснити', 'совершить'),
#  ('здогадуватися', 'догадываться'),
#  ('земель', 'земли'),
#  ('земний', 'земной'),
#  ('з-за', 'из-за'),
#  ('зима', 'зимы'),
#  ('зиму', 'зима'),
#  ('зіграти', 'сыграть'),
#  ('зійти', 'сойти'),
#  ('зірвати', 'сорвать'),
#  ('зірка', 'звезда'),
#  ('зірки', 'звёзды'),
#  ('зламати', 'сломать'),
#  ('злочинець', 'преступник'),
#  ('злочин', 'преступление'),
#  ('злука', 'соединение'),
#  ('зміна', 'изменение'),
#  ('зміна', 'смена'),
#  ('змінити', 'измениться'),
#  ('зміст', 'содержание'),
#  ('зміцнення', 'укрепление'),
#  ('знадобитися', 'понадобиться'),
#  ('знайомитися', 'познакомиться'),
#  ('знайомство', 'знакомство'),
#  ('знайти', 'находить'),
#  ('знаряддя', 'орудие'),
#  ('знати', 'знать'),
#  ('значний', 'значительный'),
#  ('значно', 'значительно'),
#  ('зненацька', 'внезапно'),
#  ('знизу', 'дно'),
#  ('знизу', 'снизу'),
#  ('зникати', 'исчезать'),
#  ('зникати', 'исчезнуть'),
#  ('зникнути', 'исчезнуть'),
#  ('знову', 'опять'),
#  ('знову', 'снова'),
#  ('зображення', 'изображение'),
#  ('зображення', 'картина'),
#  ('зокрема', 'частность'),
#  ('зошит', 'тетрадь'),
#  ('з-під', 'из-под'),
#  ('зрада', 'измена'),
#  ('зрадіти', 'обрадоваться'),
#  ('зразок', 'образец'),
#  ('зрозумілий', 'понятный'),
#  ('зростання', 'рост'),
#  ('з', 'с'),
#  ('з', 'со'),
#  ('зупинити', 'останавливаться'),
#  ('зупинити', 'остановить'),
#  ('зупинити', 'переставать'),
#  ('зупинка', 'остановка'),
#  ('зусилля', 'усилие'),
#  ('і', 'а'),
#  ('ігри', 'игра'),
#  ('ігри', 'игры'),
#  ('ізба', 'изба'),
#  ('і', 'и'),
#  ('імператор', 'император'),
#  ('імперія', 'империя'),
#  ('інженер', 'инженер'),
#  ('іноді', 'иногда'),
#  ('іноземець', 'иностранец'),
#  ('інспектор', 'инспектор'),
#  ('інспектор', 'следователь'),
#  ('інститут', 'институт'),
#  ('інструмент', 'инструмент'),
#  ('інтерес', 'интерес'),
#  ('інше', 'остальное'),
#  ('інше', 'покой'),
#  ('інший', 'другой'),
#  ('інший', 'иной'),
#  ('інший', 'прочий'),
#  ('іскра', 'искра'),
#  ('існування', 'существование'),
#  ('існувати', 'существовать'),
#  ('іспит', 'экзамен'),
#  ('істина', 'TRUE'),
#  ('істинний', 'истинный'),
#  ('історія', 'рассказ'),
#  ('їдальня', 'столовая'),
#  ('їжак', 'ёж'),
#  ('їжа', 'пища'),
#  ('її', 'ей'),
#  ('їм', 'им'),
#  ('їхати', 'ехать'),
#  ('їх', 'их'),
#  ('йому', 'ему'),
#  ('йти', 'ездить'),
#  ('йти', 'ехать'),
#  ('йти', 'идти'),
#  ('йти', 'пойти'),
#  ('йти', 'ходить'),
#  ('кабіна', 'кабина'),
#  ('кава', 'кофе'),
#  ('кавун', 'арбуз'),
#  ('кажуть', 'мол'),
#  ('казка', 'сказка'),
#  ('камери', 'камера'),
#  ('каміння', 'камни'),
#  ('капелюх', 'шляпа'),
#  ('капітал', 'столица'),
#  ('капітан', 'капитан'),
#  ('каплиця', 'часовня'),
#  ('картка', 'карточка'),
#  ('кафедрою', 'стул'),
#  ('квапитися', 'броситься'),
#  ('квапитися', 'торопиться'),
#  ('квапливий', 'торопливый'),
#  ('квиток', 'билет'),
#  ('квітень', 'апрель'),
#  ('кепсько', 'плохо'),
#  ('керівник', 'голова'),
#  ('керівники', 'головы'),
#  ('керівники', 'начальство'),
#  ('керівник', 'руководитель'),
#  ('кермо', 'руль'),
#  ('кивають', 'кивать'),
#  ('кидати', 'бросать'),
#  ('кидатися', 'бросаться'),
#  ('килим', 'ковер'),
#  ('килим', 'ковёр'),
#  ('китайська', 'китайский'),
#  ('кишеня', 'карман'),
#  ('кімната', 'комната'),
#  ('кінець', 'конец'),
#  ('кінчається', 'кончаться'),
#  ('кістка', 'кость'),
#  ('кішка', 'кот'),
#  ('кішка', 'кошка'),
#  ('клас', 'класс'),
#  ('класти', 'класть'),
#  ('клітина', 'клетка'),
#  ('клопотання', 'ходатайство'),
#  ('книги', 'книга'),
#  ('книги', 'книжка'),
#  ('ковдра', 'одеяло'),
#  ('ковток', 'глоток'),
#  ('кожен', 'всякая'),
#  ('кожен', 'всякий'),
#  ('колгосп', 'колхоз'),
#  ('колега', 'коллега'),
#  ('колектив', 'коллектив'),
#  ('коли', 'когда'),
#  ('колиска', 'колыбель'),
#  ('колискова', 'колыбельная'),
#  ('колись', 'некогда'),
#  ('колір', 'цвет'),
#  ('колоду', 'бревно'),
#  ('коло', 'круг'),
#  ('коло', 'круги'),
#  ('коло', 'кружок'),
#  ('колона', 'колонна'),
#  ('командувати', 'командовать'),
#  ('комаха', 'насекомое'),
#  ('комісар', 'комиссар'),
#  ('комісія', 'комиссия'),
#  ('комітет', 'комитет'),
#  ('комуністичний', 'коммунистический'),
#  ('комуніст', 'коммунист'),
#  ('конкретний', 'конкретный'),
#  ('концепція', 'понятие'),
#  ('коня', 'конь'),
#  ('корабель', 'корабль'),
#  ('кореспондент', 'корреспондент'),
#  ('корисний', 'полезный'),
#  ('користь', 'польза'),
#  ('коричневий', 'коричневый'),
#  ('королеви', 'королева'),
#  ('космічний', 'космический'),
#  ('коханка', 'любовница'),
#  ('краватка', 'галстук'),
#  ('крам', 'наследие'),
#  ('крамниця', 'магазин'),
#  ('краплинка', 'капелька'),
#  ('краса', 'красота'),
#  ('красуня', 'красавица'),
#  ('крейда', 'мел'),
#  ('креслення', 'черчение'),
#  ('кривий', 'кривой'),
#  ('крижаний', 'ледяной'),
#  ('крило', 'крыло'),
#  ('кричати', 'орать'),
#  ('кришка', 'крышка'),
#  ('крізь', 'сквозь'),
#  ('крізь', 'через'),
#  ('крім', 'помимо'),
#  ('крісло', 'кресло'),
#  ('кроків', 'шаги'),
#  ('крокувати', 'шагать'),
#  ('крок', 'шаг'),
#  ('крутий', 'крутой'),
#  ('культурний', 'культурный'),
#  ('куля', 'шар'),
#  ('купити', 'покупать'),
#  ('купувати', 'покупать'),
#  ('куточок', 'уголок'),
#  ('кухоль', 'кружка'),
#  ('куштувати', 'пробовать'),
#  ('ланцюг', 'цепь'),
#  ('ласкаво', 'ласково'),
#  ('легень', 'легкое'),
#  ('лекція', 'лекция'),
#  ('лелека', 'аист'),
#  ('ленінградський', 'ленинградский'),
#  ('лист', 'буква'),
#  ('листопад', 'ноябрь'),
#  ('лихо', 'горе'),
#  ('лицар', 'рыцарь'),
#  ('лише', 'лишь'),
#  ('ліворуч', 'слева'),
#  ('лідер', 'лидер'),
#  ('ліжко', 'кровать'),
#  ('лікар', 'врач'),
#  ('лікарі', 'врачи'),
#  ('лікарня', 'больница'),
#  ('ліки', 'лекарства'),
#  ('ліки', 'лекарство'),
#  ('лікоть', 'локоть'),
#  ('лікування', 'лечение'),
#  ('лінія', 'линия'),
#  ('лісовий', 'лесной'),
#  ('літак', 'самолёт'),
#  ('літати', 'летать'),
#  ('література', 'литература'),
#  ('літературний', 'литературный'),
#  ('літо', 'лето'),
#  ('ліхтар', 'фонарь'),
#  ('лічильник', 'метр'),
#  ('лічильник', 'счетчик'),
#  ('ловити', 'ловить'),
#  ('льотчик', 'летчик'),
#  ('льох', 'погреб'),
#  ('любити', 'любить'),
#  ('людина', 'человек'),
#  ('людство', 'человечество'),
#  ('лютий', 'февраль'),
#  ('лякатися', 'бояться'),
#  ('лялька', 'кукла'),
#  ('мавпа', 'обезьяна'),
#  ('майбутнє', 'будущее'),
#  ('майбутній', 'будущий'),
#  ('майже', 'почти'),
#  ('майстер', 'мастер'),
#  ('майстерня', 'мастерская'),
#  ('малювати', 'рисовать'),
#  ('малюнок', 'рисунок'),
#  ('марно', 'зря'),
#  ('мастило', 'смазка'),
#  ('матеріал', 'материал'),
#  ('матеріал', 'материальный'),
#  ('матері', 'матери'),
#  ('махати', 'махать'),
#  ('медичний', 'медицинский'),
#  ('межа', 'предел'),
#  ('мене', 'меня'),
#  ('менше', 'менее'),
#  ('мережа', 'сеть'),
#  ('мерщій', 'скорее'),
#  ('метал', 'металл'),
#  ('мета', 'цель'),
#  ('методу', 'метода'),
#  ('механізм', 'механизм'),
#  ('мимоволі', 'невольно'),
#  ('ми', 'мы'),
#  ('минути', 'миновать'),
#  ('мирний', 'мирный'),
#  ('мисливець', 'охотник'),
#  ('мисливські', 'охота'),
#  ('мистецтво', 'искусство'),
#  ('митниця', 'таможня'),
#  ('миттєвих', 'мгновение'),
#  ('миттєво', 'мгновенно'),
#  ('мить', 'миг'),
#  ('міліція', 'милиция'),
#  ('мільйон', 'миллион'),
#  ('міна', 'мина'),
#  ('міністерство', 'министерство'),
#  ('міністр', 'министр'),
#  ('міняти', 'менять'),
#  ('міра', 'мера'),
#  ('міркування', 'соображение'),
#  ('містер', 'мистер'),
#  ('містити', 'содержать'),
#  ('місто', 'город'),
#  ('місце', 'место'),
#  ('місці', 'очко'),
#  ('мішок', 'сумка'),
#  ('мла', 'мгла'),
#  ('млява', 'вялая'),
#  ('мови', 'языки'),
#  ('мовчання', 'тишина'),
#  ('мовчати', 'помолчать'),
#  ('моему', 'мой'),
#  ('може', 'мочь'),
#  ('можливо', 'вероятно'),
#  ('мозок', 'мозг'),
#  ('молодість', 'молодость'),
#  ('молодь', 'молодежь'),
#  ('московський', 'москва'),
#  ('мотузка', 'веревка'),
#  ('мрія', 'мечта'),
#  ('мріяти', 'мечтать'),
#  ('музичний', 'музыкальный'),
#  ('муляр', 'каменщик'),
#  ('мури', 'стены'),
#  ('набір', 'множество'),
#  ('набрати', 'набрать'),
#  ('навіть', 'даже'),
#  ('навіщо', 'зачем'),
#  ('навмисне', 'нарочно'),
#  ('навпаки', 'наоборот'),
#  ('навчити', 'научить'),
#  ('навчитися', 'научиться'),
#  ('нагадати', 'напоминать'),
#  ('надзвичайно', 'чрезвычайно'),
#  ('надійний', 'надежный'),
#  ('наділ', 'надел'),
#  ('надія', 'надежда'),
#  ('надходити', 'поступать'),
#  ('наздогнати', 'догнать'),
#  ('назустріч', 'навстречу'),
#  ('найбільший', 'наиболее'),
#  ('найбільший', 'самый'),
#  ('належати', 'принадлежать'),
#  ('намету', 'палатка'),
#  ('намисто', 'ожерелье'),
#  ('напевно', 'видимо'),
#  ('напевно', 'возможно'),
#  ('напередоднi', 'накануне'),
#  ('напередодні', 'накануне'),
#  ('напис', 'надпись'),
#  ('на', 'по'),
#  ('напруга', 'напряжение'),
#  ('напрямок', 'направление'),
#  ('наради', 'встреча'),
#  ('наречена', 'невеста'),
#  ('народження', 'рождение'),
#  ('народити', 'родить'),
#  ('наруга', 'надругательство'),
#  ('населення', 'население'),
#  ('наскільки', 'насколько'),
#  ('наслідок', 'следствие'),
#  ('наслідувати', 'последовать'),
#  ('наступати', 'наступать'),
#  ('наступне', 'вслед'),
#  ('натиснути', 'нажать'),
#  ('натовпу', 'толпы'),
#  ('нахилитися', 'наклониться'),
#  ('нащадки', 'потомки'),
#  ('небезпека', 'опасность'),
#  ('невимовно', 'неописуемо'),
#  ('невідворотність', 'неотвратимость'),
#  ('невідомий', 'неведомый'),
#  ('негайно', 'немедленно'),
#  ('неділя', 'воскресенье'),
#  ('недолік', 'недостаток'),
#  ('недосконалість', 'трудно'),
#  ('незалежний', 'независимый'),
#  ('незвичайний', 'необыкновенный'),
#  ('неї', 'неё'),
#  ('немає', 'нет'),
#  ('немає', 'нету'),
#  ('немов', 'словно'),
#  ('немолодий', 'пожилой'),
#  ('ненавидіти', 'ненавидеть'),
#  ('необхідність', 'необходимость'),
#  ('необхідно', 'требоваться'),
#  ('неодмінно', 'непременно'),
#  ('неохайність', 'неряшливость'),
#  ('непогано', 'неплохо'),
#  ('неподалік', 'неподалеку'),
#  ('непокора', 'неповиновение'),
#  ('непомітно', 'незаметно'),
#  ('неприємний', 'неприятный'),
#  ('несамовитий', 'неистовый'),
#  ('нескінченний', 'бесконечный'),
#  ('несподівано', 'неожиданно'),
#  ('нестися', 'нестись'),
#  ('нею', 'ней'),
#  ('нижче', 'внизу'),
#  ('нижче', 'ниже'),
#  ('нині', 'ныне'),
#  ('нині', 'нынче'),
#  ('ніготь', 'ноготь'),
#  ('ніжка', 'ножка'),
#  ('ніжний', 'нежный'),
#  ('ніколи', 'никогда'),
#  ('нікому', 'никому'),
#  ('німецький', 'германский'),
#  ('німеччина', 'германия'),
#  ('ніс', 'нос'),
#  ('ніхто', 'никого'),
#  ('ніхто', 'никто'),
#  ('нічого', 'нечего'),
#  ('ніяково', 'неловко'),
#  ('новину', 'новость'),
#  ('носи', 'носы'),
#  ('нотатник', 'блокнот'),
#  ('нравится', 'нравиться'),
#  ('нравится', 'понравиться'),
#  ('ну', 'хорошо'),
#  ('нього', 'нём'),
#  ('обговорювати', 'обсуждать'),
#  ('обгрунтувати', 'обосновать'),
#  ('обдурити', 'обмануть'),
#  ('обидва', 'оба'),
#  ('обійми', 'объятия'),
#  ('обійти', 'обойти'),
#  ('області', 'поле'),
#  ('обмін', 'обмен'),
#  ('обожнює', 'боготворит'),
#  ('образитися', 'обидеться'),
#  ('обрій', 'горизонт'),
#  ('обставина', 'обстоятельство'),
#  ('обсяг', 'объем'),
#  ...]

# %% [markdown]
# ## Embedding space mapping

# %% [markdown]
# Let $x_i \in \mathrm{R}^d$ be the distributed representation of word $i$ in the source language, and $y_i \in \mathrm{R}^d$ is the vector representation of its translation. Our purpose is to learn such linear transform $W$ that minimizes euclidian distance between $Wx_i$ and $y_i$ for some subset of word embeddings. Thus we can formulate so-called Procrustes problem:
#
# $$W^*= \arg\min_W \sum_{i=1}^n||Wx_i - y_i||_2$$
# or
# $$W^*= \arg\min_W ||WX - Y||_F$$
#
# where $||*||_F$ - Frobenius norm.
#
# In Greek mythology, Procrustes or "the stretcher" was a rogue smith and bandit from Attica who attacked people by stretching them or cutting off their legs, so as to force them to fit the size of an iron bed. We make same bad things with source embedding space. Our Procrustean bed is target embedding space.

# %% [markdown]
# ![embedding_mapping.png](https://github.com/yandexdataschool/nlp_course/raw/master/resources/embedding_mapping.png)

# %% [markdown]
# ![procrustes.png](https://github.com/yandexdataschool/nlp_course/raw/master/resources/procrustes.png)

# %% [markdown]
# But wait...$W^*= \arg\min_W \sum_{i=1}^n||Wx_i - y_i||_2$ looks like simple multiple linear regression (without intercept fit). So let's code.

# %%
from sklearn.linear_model import LinearRegression

# YOUR CODE HERE
mapping = LinearRegression(fit_intercept = False)
mapping.fit(X_train, Y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %% [markdown]
# Let's take a look at neigbours of the vector of word _"серпень"_ (_"август"_ in Russian) after linear transform.

# %%
august = mapping.predict(uk_emb["серпень"].reshape(1, -1))
ru_emb.most_similar(august)
# Out:
# [('апрель', 0.8541285991668701),
#  ('июнь', 0.8411202430725098),
#  ('март', 0.839699387550354),
#  ('сентябрь', 0.835986852645874),
#  ('февраль', 0.8329297304153442),
#  ('октябрь', 0.8311845660209656),
#  ('ноябрь', 0.8278923630714417),
#  ('июль', 0.8234528303146362),
#  ('август', 0.812049925327301),
#  ('декабрь', 0.803900420665741)]

# %%
ru_emb.most_similar(august)[0][0]
# Out:
# 'апрель'

# %% [markdown]
# We can see that neighbourhood of this embedding cosists of different months, but right variant is on the ninth place.

# %% [markdown]
# As quality measure we will use precision top-1, top-5 and top-10 (for each transformed Ukrainian embedding we count how many right target pairs are found in top N nearest neighbours in Russian embedding space).

# %%
def precision(pairs, mapped_vectors, topn=1):
    """
    :args:
        pairs = list of right word pairs [(uk_word_0, ru_word_0), ...]
        mapped_vectors = list of embeddings after mapping from source embedding space to destination embedding space
        topn = the number of nearest neighbours in destination embedding space to choose from
    :returns:
        precision_val, float number, total number of words for those we can find right translation at top K.
    """
    assert len(pairs) == len(mapped_vectors)
    num_matches = 0
    for i, (_, ru) in enumerate(pairs):
      for j in range (topn):
        if ru == ru_emb.most_similar(mapped_vectors[i], topn = topn)[j][0]:
          num_matches += 1

    precision_val = num_matches / len(pairs)
    return precision_val

# %%
precision([("серпень", "август")], august, topn=9)
# Out:
# 1.0

# %%
assert precision([("серпень", "август")], august, topn=5) == 0.0
assert precision([("серпень", "август")], august, topn=9) == 1.0
assert precision([("серпень", "август")], august, topn=10) == 1.0

# %%
assert precision(uk_ru_test, X_test) == 0.0
assert precision(uk_ru_test, Y_test) == 1.0

# %%
precision_top1 = precision(uk_ru_test, mapping.predict(X_test), 1)
precision_top5 = precision(uk_ru_test, mapping.predict(X_test), 5)

assert precision_top1 >= 0.635
assert precision_top5 >= 0.813

# %% [markdown]
# ## Making it better (orthogonal Procrustean problem)

# %% [markdown]
# It can be shown (see original paper) that a self-consistent linear mapping between semantic spaces should be orthogonal.
# We can restrict transform $W$ to be orthogonal. Then we will solve next problem:
#
# $$W^*= \arg\min_W ||WX - Y||_F \text{, where: } W^TW = I$$
#
# $$I \text{- identity matrix}$$
#
# Instead of making yet another regression problem we can find optimal orthogonal transformation using singular value decomposition. It turns out that optimal transformation $W^*$ can be expressed via SVD components:
# $$X^TY=U\Sigma V^T\text{, singular value decompostion}$$
# $$W^*=UV^T$$

# %%
def learn_transform(X_train, Y_train):
    """
    :returns: W* : float matrix[emb_dim x emb_dim] as defined in formulae above
    """
    # YOU CODE HERE
    W = np.linalg.svd(X_train.T @ Y_train)[0] @ np.linalg.svd(X_train.T @ Y_train)[2]
    return W

# %%
np.linalg.svd(X_train.T @ Y_train)[0] @ np.linalg.svd(X_train.T @ Y_train)[2]
# Out:
# array([[-0.04726665, -0.00039402,  0.0166095 , ...,  0.01075437,
#          0.05630342, -0.02920353],
#        [ 0.01875367,  0.07762799, -0.02526668, ..., -0.04825173,
#          0.05523333,  0.0028777 ],
#        [-0.00289267,  0.00492186,  0.03302287, ..., -0.09383111,
#          0.00108156, -0.0254705 ],
#        ...,
#        [ 0.06924206,  0.02402487,  0.00025697, ..., -0.10238964,
#         -0.01046239, -0.01620156],
#        [ 0.07994907,  0.03983814,  0.06650171, ...,  0.05040337,
#          0.10387792, -0.06498559],
#        [ 0.00486824,  0.04323363, -0.03774837, ..., -0.00240079,
#         -0.07146891, -0.00777117]], dtype=float32)

# %%
W = learn_transform(X_train, Y_train)

# %%
ru_emb.most_similar([np.matmul(uk_emb["серпень"], W)])[0][0]
# Out:
# 'апрель'

# %%
assert precision(uk_ru_test, np.matmul(X_test, W)) >= 0.653
assert precision(uk_ru_test, np.matmul(X_test, W), 5) >= 0.824

# %% [markdown]
# ## UK-RU Translator

# %% [markdown]
# Now we are ready to make simple word-based translator: for each word in source language in shared embedding space we find the nearest in target language.

# %%
with open("/content/drive/MyDrive/ysda/fairy_tale.txt", "r") as inpf:
    uk_sentences = [line.rstrip().lower() for line in inpf]

# %%
from nltk.tokenize import WordPunctTokenizer
def translate(sentence):
    """
    :args:
        sentence - sentence in Ukrainian (str)
    :returns:
        translation - sentence in Russian (str)

    * find ukrainian embedding for each word in sentence
    * transform ukrainian embedding vector
    * find nearest russian word and replace
    """
    # YOUR CODE HERE
    ans = ''
    tokenizer = WordPunctTokenizer()
    sentence = [j.lower() for j in tokenizer.tokenize(sentence)]
    for word in sentence:
      if word in uk_emb.key_to_index:
       new_word = ru_emb.most_similar([np.matmul(uk_emb[word], W)])[0][0]
       ans += new_word + ' '

    return ans[:-1]

# %%
assert translate(".") == "."
assert translate("1 , 3") == "1 , 3"
assert translate("кіт зловив мишу") == "кот поймал мышку"

# %%
for sentence in uk_sentences:
    print("src: {}\ndst: {}\n".format(sentence, translate(sentence)))
# Out:
# src: лисичка - сестричка і вовк - панібрат
# dst: лисичка – сестричка и волк –
#
# src: як була собі лисичка та зробила хатку, та й живе. а це приходять холоди. от лисичка замерзла та й побігла в село вогню добувать, щоб витопити. прибігає до одної баби та й каже:
# dst: как была себе лисичка и сделала избушку , и и живет . а оно приходят морозы . из лисичка замерзла и и побежала во село огня , чтобы . прибегает к одной бабы и и говорит :
#
# src: — здорові були, бабусю! з неділею... позичте мені огню, я вам одслужу.
# dst: — здоровые были , бабушку ! со воскресеньем ... мне огня , мной тебе .
#
# src: — добре, — каже, — лисичко - сестричко. сідай погрійся трохи, поки я пиріжечки повибираю з печі!
# dst: — хорошо , — говорит , — – сестричка . садись немного , пока мной пирожки со печи !
#
# src: а баба макові пиріжки пекла. от баба вибирає пиріжки та на столі кладе, щоб прохололи; а лисичка підгляділа та за пиріг, та з хати... виїла мачок із середини, а туди напхала сміттячка, стулила та й біжить.
# dst: а бабка маковые пирожки ада . из бабка выбирает пирожки и по столе кладет , чтобы ; а лисичка и за пирог , и со хаты ... со середины , а туда , и и бежит .
#
# src: от біжить, а хлопці товар женуть до води.
# dst: из бежит , а парни товар гонят к воды .
#
# src: — здорові були, хлопці!
# dst: — здоровые были , парни !
#
# src: — здорова, лисичко - сестричко!
# dst: — здоровая , – сестричка !
#
# src: — проміняйте мені бичка - третячка на маковий пиріжок!
# dst: — мне бычка – по маковый пирожок !
#
# src: — добре, — кажуть.
# dst: — хорошо , — дескать .
#
# src: — тільки, — каже, — тепер не їжте, а як я вибіжу з села, то тоді.
# dst: — только , — говорит , — теперь не ешьте , а как мной со деревни , то тогда .
#
# src: от помінялись. лисичка за бичка — та в ліс. а хлопці до пиріжка — а там сміттянко.
# dst: из поменяются . лисичка за бычка — и во лес . а парни к пирожка — а там .
#
# src: от прибігла лисичка до своєї хатки, вирубала дерево, зробила санки, запрягла бичка — іде. аж біжить вовк:
# dst: из прибежала лисичка к своего хатки , дерево , сделала санки , бычка — идет . аж бежит волк :
#
# src: — здорова, лисичко - сестричко!
# dst: — здоровая , – сестричка !
#
# src: — здоров, вовчику - братику!
# dst: — здоровье , – братику !
#
# src: — де ти взяла бичка - третячка і санки?
# dst: — куда ты взяла бычка – и санки ?
#
# src: — зробила собі!
# dst: — сделала себе !
#
# src: — підвези ж, — каже, — мене, лисичко - сестричко!
# dst: — же , — говорит , — меня , – сестричка !
#
# src: — е, куди я тебе візьму? ти мені й санки поламаєш!
# dst: — ьн , куда мной тебя возьму ? ты мне и санки !
#
# src: — ні, — каже, — я тільки одну ніжку положу.
# dst: — ни , — говорит , — мной только одну ножку .
#
# src: — ну, клади!
# dst: — ну , дощечки !
#
# src: от од’їхали трохи, вовк і каже:
# dst: из от со ехали немного , волк и говорит :
#
# src: — положу я, лисичко - сестричко, й другу ніжку!
# dst: — мной , – сестричка , и вторую ножку !
#
# src: — е, вовчику - братику, ти мені й санки поламаєш!
# dst: — ьн , – братику , ты мне и санки !
#
# src: — ні, — каже, — не поламаю!
# dst: — ни , — говорит , — не !
#
# src: — ну, клади!
# dst: — ну , дощечки !
#
# src: вовк і положив. ідуть, їдуть, коли це щось — трісь.
# dst: волк и положил . идут , едут , когда оно что-то — .
#
# src: — е, вовчику - братику, ти мені вже й санки ламаєш!
# dst: — ьн , – братику , ты мне уже и санки !
#
# src: — ні лисичко - сестричко, то я орішок розкусив.
# dst: — ни – сестричка , то мной .
#
# src: — ну, гляди!
# dst: — ну , девки !
#
# src: от їдуть...
# dst: из едут ...
#
# src: — положу я, лисичко - сестричко, й третю ніжку! — каже вовк.
# dst: — мной , – сестричка , и третью ножку ! — говорит волк .
#
# src: — куди ти положиш? ти мені санки поламаєш! чим я тоді дровець привезу?
# dst: — куда ты ? ты мне санки ! Чем мной тогда привезу ?
#
# src: — ні, — каже, — не поламаю.
# dst: — ни , — говорит , — не .
#
# src: — ну, клади.
# dst: — ну , дощечки .
#
# src: вовк положив і третю ногу. коли це — трісь!
# dst: волк положил и третью ногу . когда оно — !
#
# src: — ой лихо! — каже лисичка. — йди собі геть, вовчику, — ти мені зовсім санки поламаєш.
# dst: — ой горе ! — говорит лисичка . — иди себе прочь , , — ты мне совсем санки .
#
# src: — ні, то я орішок розкусив!
# dst: — ни , то мной !
#
# src: — дай же й мені!
# dst: — дай то и мне !
#
# src: — нема, — каже, — останній!
# dst: — нету , — говорит , — последний !
#
# src: їдуть собі та й їдуть; вовчик і каже:
# dst: едут себе и и едут ; и говорит :
#
# src: — сяду я зовсім, лисичко!
# dst: — сяду мной совсем , !
#
# src: — куди ти сядеш, вовчику - братику? і санки розламаєш!
# dst: — куда ты сяду , – братику ? и санки !
#
# src: — я помаленьку, — каже.
# dst: — мной потихоньку , — говорит .
#
# src: — ну, гляди!
# dst: — ну , девки !
#
# src: от вовчик тільки що сів, а санки так і розпались... лисичка тоді давай його лаять! лаяла - лаяла та й каже:
# dst: из только что уселся , а санки так и распались ... лисичка тогда давай его ! ругала – ругала и и говорит :
#
# src: — піди ж, сякий - такий сину, дровець нарубай і на санки вирубай, і приволочи!
# dst: — пойди же , – такой сыну , и по санки , и !
#
# src: — як же я, — каже вовчик, — вирубаю, коли я не знаю, якого дерева?
# dst: — как то мной , — говорит , — , когда мной не знаю , которого деревья ?
#
# src: — е, — сякий - такий сину! як санчата ламать, так і знав, а дровець вирубать, то й ні!
# dst: — ьн , — – такой сыну ! как санки , так и знал , а , то и ни !
#
# src: коришувала його, коришувала...
# dst: его , ...
#
# src: — як увійдеш, — каже, — в ліс, то кажи: « рубайся, дерево, й пряме, й криве! рубайся, дерево, й пряме, й криве! »
# dst: — как , — говорит , — во лес , то говори : « , дерево , и прямое , и кривое ! , дерево , и прямое , и кривое ! »
#
# src: вовк і пішов.
# dst: волк и пошел .
#
# src: от приходить в ліс та й каже:
# dst: из приходит во лес и и говорит :
#
# src: — рубайся, дерево, криве й криве!
# dst: — , дерево , кривое и кривое !
#
# src: дерево й нарубалось. таке корячкувате, що й на палицю не вибереш — не то на полозок! приносить вовчик до лисички те дерево. вона як подивилась, давай його знов батькувати.
# dst: дерево и . такое , что и по палку не выберешь — не то по ! приносит к лисички что дерево . она как посмотрела , давай его снова .
#
# src: — ти, — каже, — сякий - такий сину, не так казав, як я тобі веліла!
# dst: — ты , — говорит , — – такой сыну , не так говорил , как мной тебе велела !
#
# src: — ні, лисичко - сестричко, я, — каже, — стояв та все казав: « рубайся, дерево, криве й криве! »
# dst: — ни , – сестричка , мной , — говорит , — стоял и всё говорил : « , дерево , кривое и кривое ! »
#
# src: — е, бісів сину, й того недотепний! ну, сиди ж ти тут, — я сама піду нарубаю.
# dst: — ьн , бесов сыну , и того ! ну , сиди же ты здесь , — мной сама пойду .
#
# src: та й пішла.
# dst: и и пошла .
#
# src: от сидить вовк сам собі — так їсти хочеться! він думав - думав: « давай, — каже, — з’їм бичка та й утечу! » от взяв проїв дірку у бичка, із середини все виїв, а туди горобців напустив і соломою заткнув, а сам — драла... приходить лисичка, зробила санчата, сіла...
# dst: из сидит волк сам себе — так кушать хочется ! он думал – думал : « давай , — говорит , — со со им бычка и и побег ! » из взял дыру во бычка , со середины всё , а туда воробьёв напустил и соломой заткнул , а сам — деру ... приходит лисичка , сделала санки , присела ...
#
# src: — гей, бичок - третячок!
# dst: — гей , бычок – !
#
# src: аж бичок не везе. вона його батогом. як ударила, а віхоть соломи й випав; а горобці — хррр!
# dst: аж бычок не увозит . она его хлыстом . как ударила , а соломы и выпал ; а воробьи — !
#
# src: — а, сякий - такий вовчик! постій же, — каже, — я тобі згадаю!
# dst: — а , – такой ! постой то , — говорит , — мной тебе вспомню !
#
# src: та й пішла...
# dst: и и пошла ...
#
# src: лягла на шляху та й лежить. ідуть чумаки з рибою; вона притаїлась, мов нежива. чумаки дивляться — аж лисиця:
# dst: легла по пути и и лежит . идут казаки со рыбой ; она , языки неживая . казаки смотрят — аж лисица :
#
# src: — візьмім, — кажуть, — бра, та продамо — буде за що хоч погрітися!
# dst: — , — дескать , — бра , и продадим — будет за что хоть погреться !
#
# src: скинули її на останній віз та й поїхали. ідуть та й їдуть. а лисичка - сестричка бачить, що вони не дивляться, та все кида по рибці на дорогу, все кида... от як накидала вже багато, тоді нишком і сама злізла. чумаки ж поїхали собі далі, а вона позбирала рибку, сіла та й їсть.
# dst: сбросили ей по последний визы и и поехали . идут и и едут . а лисичка – сестричка видит , что они не смотрят , и всё по рыбки по дорогу , всё ... из как навязала уже много , тогда втихаря и сама слезла . казаки же поехали себе дальше , а она рыбку , присела и и ест .
#
# src: коли це біжить вовчик:
# dst: когда оно бежит :
#
# src: — здорова була, лисичко - сестричко!
# dst: — здоровая была , – сестричка !
#
# src: — здоров, вовчику - братику!
# dst: — здоровье , – братику !
#
# src: — що ти робиш, лисичко - сестричко?
# dst: — что ты делаешь , – сестричка ?
#
# src: — рибу, — каже, — їм.
# dst: — рыбу , — говорит , — им .
#
# src: — дай же й мені!
# dst: — дай то и мне !
#
# src: — піди собі налови.
# dst: — пойди себе .
#
# src: — так як же я наловлю, коли я не вмію?
# dst: — так как то мной , когда мной не умею ?
#
# src: — ну, як знаєш, а я не дам і кісточки!
# dst: — ну , как знаешь , а мной не дам и косточки !
#
# src: — так хоч навчи мене, як наловить.
# dst: — так хоть научить меня , как .
#
# src: а лисичка й дума: « постій же! ти мого бичка - третячка з’їв — я тепер тобі оддячу! »
# dst: а лисичка и дума : « постой то ! ты моего бычка – со со ел — мной теперь тебе ! »
#
# src: — а так, — каже, — піди до ополонки, устроми в ополонку хвіст та потихеньку води ним і приказуй: « ловись, рибко, мала й велика! ловись, рибко, мала й велика! » то вона й наловиться.
# dst: — а так , — говорит , — пойди к проруби , во прорубь хвост и потихоньку воды ним и : « , рыбка , имела и большая ! , рыбка , имела и большая ! » то она и .
#
# src: — ну, спасибі за науку! — каже вовчик.
# dst: — ну , спасибо за науку ! — говорит .
#
# src: от прибігає вовчик до ополонки, устромив в ополонку хвіст:
# dst: из прибегает к проруби , во прорубь хвост :
#
# src: — ловись, — каже, — рибко, мала й велика!
# dst: — , — говорит , — рыбка , имела и большая !
#
# src: а лисичка з очерету:
# dst: а лисичка со камыша :
#
# src: — мерзни, мерзни, вовчий хвіст!
# dst: — , , волчий хвост !
#
# src: а мороз надворі такий, що аж шкварчить! вовчик хвостиком усе водить та:
# dst: а мороз дворе такой , что аж ! хвостиком всё водит и :
#
# src: — ловись, рибко, мала й велика!
# dst: — , рыбка , имела и большая !
#
# src: а лисичка:
# dst: а лисичка :
#
# src: — мерзни, мерзни, вовчий хвіст!
# dst: — , , волчий хвост !
#
# src: поки ловив вовчик рибу, поки хвіст так і прикипів в ополонці! тоді лисичка в село:
# dst: пока ловил рыбу , пока хвост так и пугаясь во проруби ! тогда лисичка во село :
#
# src: — ідіть, люди, вовка бить!
# dst: — идите , люди , волка мочь !
#
# src: люди як вискочать — з кочергами, з рогачами, із сокирами: вбили того вовка і пропав бідний! а лисичка й досі живе у своїй хатці.
# dst: люди как — со , со , со топорами : убили того волка и пропал бедный ! а лисичка и сих живет во своей хате .

# %% [markdown]
# Not so bad, right? We can easily improve translation using language model and not one but several nearest neighbours in shared embedding space. But next time.

# %% [markdown]
# ## Would you like to learn more?
#
# ### Articles:
# * [Exploiting Similarities among Languages for Machine Translation](https://arxiv.org/pdf/1309.4168)  - entry point for multilingual embedding studies by Tomas Mikolov (the author of W2V)
# * [Offline bilingual word vectors, orthogonal transformations and the inverted softmax](https://arxiv.org/pdf/1702.03859) - orthogonal transform for unsupervised MT
# * [Word Translation Without Parallel Data](https://arxiv.org/pdf/1710.04087)
# * [Loss in Translation: Learning Bilingual Word Mapping with a Retrieval Criterion](https://arxiv.org/pdf/1804.07745)
# * [Unsupervised Alignment of Embeddings with Wasserstein Procrustes](https://arxiv.org/pdf/1805.11222)
#
# ### Repos (with ready-to-use multilingual embeddings):
# * https://github.com/facebookresearch/MUSE
#
# * https://github.com/Babylonpartners/fastText_multilingual -
